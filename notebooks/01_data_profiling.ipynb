# %% [markdown]
# # 01 - Data Profiling
# ## Philippine DPWH Infrastructure Data Audit & Validation Suite
# This notebook performs exploratory data profiling over the raw Philippine Department of Public Works and Highways (DPWH) National Bridge dataset.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

import pandas as pd
from src.data_loader import load_dataset
from src.profiler import DataProfiler

raw_data_path = '../data/raw/national_bridges_2021.csv'
df = load_dataset(raw_data_path)
print(f"Loaded dataset shape: {df.shape[0]:,} rows x {df.shape[1]} columns")
df.head()

# %% [markdown]
# ### Statistical Profiling & Missingness Analysis

# %%
profiler = DataProfiler(df)
profile_results = profiler.profile()

print("=== DATASET PROFILE SUMMARY ===")
print(f"Total Cells: {profile_results['dataset_shape']['total_cells']:,}")
print(f"Missing Cells: {profile_results['overall_missing_cells']:,} ({profile_results['overall_missing_pct']}%)")
print(f"Duplicate BRIDGE_IDs: {profile_results['bridge_id_duplicates']}")
