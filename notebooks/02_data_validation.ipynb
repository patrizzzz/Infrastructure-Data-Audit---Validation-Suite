# %% [markdown]
# # 02 - Data Validation
# ## Multi-Dimensional Validation Rules Engine
# This notebook evaluates the raw dataset against spatial bounding boxes, structural engineering bounds, regex ID standards, and primary key uniqueness.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src.data_loader import load_dataset
from src.validator import DataValidator

df = load_dataset('../data/raw/national_bridges_2021.csv')
validator = DataValidator(df)
issues_df, val_metrics = validator.validate()

print(f"Evaluated Records: {val_metrics['total_records_evaluated']:,}")
print(f"Flagged Records: {val_metrics['flagged_records']:,}")
print(f"Total Issues Found: {val_metrics['total_issues_detected']:,}")
issues_df.head(10)
